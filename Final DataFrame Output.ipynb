# %% [markdown]
# # 1) Write a python program to display all the header tags from wikipedia.org.

# %%
#Installing the required libraries 
# !pip install bs4
# !pip install requests
#Import required libraries
#importing the required libraries
from bs4 import BeautifulSoup
import requests

# %%
#Scrapping all the header tags from wikipedia.org.
first_header=soup.find('span',class_="mw-headline")
first_header.text

#Create empty list to store the data
headers=[]  
for i in soup.find_all('span',class_="mw-headline"):
    headers.append(i.text)
    
    #Making Dataframe
import pandas as pd
df = pd.DataFrame({'All_Headers':headers})
df
# Out:
#                      All_Headers
# 0           Welcome to Wikipedia
# 1  From today's featured article
# 2               Did you know ...
# 3                    In the news
# 4                    On this day
# 5       Today's featured picture
# 6       Other areas of Wikipedia
# 7    Wikipedia's sister projects
# 8            Wikipedia languages

# %% [markdown]
# # 2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. name, rating, year of release) and make data frame.

# %%
#Making Dataframe
df = pd.DataFrame({'Name':titles,'Ratings':ratings[:100],'Year':year})
df
# Out:
#                                             Name Ratings    Year
# 0               1.The Shawshank Redemption(1994)     9.3  (1994)
# 1                          2.The Godfather(1972)     9.2  (1972)
# 2                 3.The Godfather: Part II(1974)       9  (1974)
# 3                        4.The Dark Knight(2008)       9  (2008)
# 4                           5.12 Angry Men(1957)       9  (1957)
# ..                                           ...     ...     ...
# 95                   96.North by Northwest(1959)     8.3  (1959)
# 96                   97.A Clockwork Orange(1971)     8.3  (1971)
# 97                               98.Snatch(2000)     8.3  (2000)
# 98  99.Le fabuleux destin d'Amélie Poulain(2001)     8.3  (2001)
# 99                             100.The Kid(1921)     8.3  (1921)
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. name, rating, year of release) and make data frame

# %%
    
#Making Dataframe
df = pd.DataFrame({'Name':titles[:100],'Ratings':ratings[:100],'Year':year[:100]})
df
# Out:
#                                              Name Ratings    Year
# 0                          1.      Jai Bhim(2021)     8.4  (2021)
# 1                        2.      Anbe Sivam(2003)     8.4  (2003)
# 2                           3.      Golmaal(1979)     8.4  (1979)
# 3                           4.      Nayakan(1987)     8.4  (1987)
# 4                 5.      Pariyerum Perumal(2018)     8.4  (2018)
# ..                                            ...     ...     ...
# 95                          96.      Masaan(2015)     8.0  (2015)
# 96                  97.      Dil Chahta Hai(2001)     8.0  (2001)
# 97          98.      RRR (Rise Roar Revolt)(2022)     8.0  (2022)
# 98                         99.      Kahaani(2012)     8.0  (2012)
# 99        100.      Maheshinte Prathikaaram(2016)     8.0  (2016)
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4) Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vb

# %%
#Creatting the data frame
df=pd.DataFrame({'Ladies bags':bags,'Price':price,'Discount':discount})
df
# Out:
#                              Ladies bags  Price Discount
# 0          Graceful Fancy Women Handbags   ₹528   9% off
# 1        Ravishing Classy Women Handbags   ₹950   5% off
# 2       Classic Versatile Women Handbags   ₹950   5% off
# 3           Voguish Fancy Women Handbags  ₹1549   3% off
# 4      Ravishing Alluring Women Handbags   ₹384  12% off
# 5      Graceful Versatile Women Handbags   ₹950   5% off
# 6         Classic Stylish Women Handbags  ₹3202   2% off
# 7   Ravishing Fashionable Women Handbags   ₹316  14% off
# 8          Elegant Classy Women Handbags   ₹950   5% off
# 9        Elegant Alluring Women Handbags  ₹2337   2% off
# 10       Classic Alluring Women Handbags   ₹518   9% off
# 11    Elegant Fashionable Women Handbags   ₹725   6% off
# 12        Trendy Alluring Women Handbags  ₹1320   4% off
# 13        Trendy Alluring Women Handbags   ₹950   5% off
# 14          Classic Fancy Women Handbags   ₹646   7% off
# ...

# %% [markdown]
# # 5) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

# %% [markdown]
# a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
# b) Top 10 ODI Batsmen along with the records of their team and rating.
#
# c) Top 10 ODI bowlers along with the records of their team and rating

# %%
#a) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#Creating a dataframe
import pandas as pd
ODI_Team=pd.DataFrame({'Team':team[:10],'Match':match1[:10],'Point':points1[:10],'Rating':ratings[:10]})
ODI_Team
# Out:
#            Team Match  Point Rating
# 0   New Zealand    20  2,448    122
# 1       England    32  3,793    119
# 2     Australia    31  3,475    112
# 3         India    38  4,162    110
# 4  South Africa    31  3,167    102
# 5      Pakistan    30  2,921     97
# 6    Bangladesh    36  3,350     93
# 7     Sri Lanka    35  2,835     81
# 8   West Indies    36  2,788     77
# 9   Afghanistan    23  1,562     68

# %%
#b) Top 10 ODI Batsmen along with the records of their team and rating.
import pandas as pd
odibatsmen_dict={'Name':batsmenNames,"Teams":batsmenTeams,'Rating':batsmenRatings}
odibatsmen_df=pd.DataFrame(odibatsmen_dict)

#Batsmen_dict={'POS':pos[:9],'Player':name[:9],'Team':team[:9],'Rating':rating[:9]}
#Batsmen_Dataframe=pd.DataFrame(Batsmen_dict)

odibowler_dict={'Name':bowlerNames,"Teams":bowlerTeams,'Rating':bowlerRatings}
odibowler_df=pd.DataFrame(odibowler_dict)

#Bowlers_dict={'POS':pos[:9],'Player':name[9:18],'Team':team[9:18],'Rating':rating[9:18]}
#Bowlers_df=pd.DataFrame(Bowlers_dict)

# %%
odibatsmen_df
# Out:
#                     Name Teams  Rating
# 0             Babar Azam   PAK     891
# 1            Virat Kohli   IND     811
# 2            Imam-ul-Haq   PAK     795
# 3           Rohit Sharma   IND     791
# 4        Quinton de Kock    SA     789
# 5         Jonny Bairstow   ENG     775
# 6            Ross Taylor    NZ     775
# 7  Rassie van der Dussen    SA     769
# 8           David Warner   AUS     750
# 9            Aaron Finch   AUS     745

# %%
#c) Top 10 ODI bowlers along with the records of their team and rating
odibowler_df
# Out:
#                Name Teams  Rating
# 0       Trent Boult    NZ     726
# 1      Chris Woakes   ENG     700
# 2    Josh Hazlewood   AUS     698
# 3        Matt Henry    NZ     683
# 4  Mujeeb Ur Rahman   AFG     681
# 5    Jasprit Bumrah   IND     679
# 6    Shaheen Afridi   PAK     671
# 7      Mehedi Hasan   BAN     661
# 8   Shakib Al Hasan   BAN     657
# 9       Rashid Khan   AFG     650

# %% [markdown]
# # 6) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:

# %% [markdown]
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
#
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating

# %%
#a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.


#Creating a dataframe
import pandas as pd
ODI_Women_Team=pd.DataFrame({'Team':team[:10],'Match':match1[:10],'Point':points1[:10],'Rating':ratings[:10]})
ODI_Women_Team
# Out:
#            Team Match  Point Rating
# 0     Australia    29  4,840    167
# 1  South Africa    28  3,504    125
# 2       England    30  3,533    118
# 3         India    29  2,878     99
# 4   New Zealand    31  3,030     98
# 5   West Indies    28  2,481     89
# 6    Bangladesh    12    936     78
# 7      Pakistan    26  1,752     67
# 8       Ireland     5    240     48
# 9     Sri Lanka     5    233     47

# %%
#b) Top 10 women’s ODI Batting players along with the records of their team and rating.

#Creaing the dataframe
import pandas as pd
odibatsmen_dict={'Name':batsmenNames,"Teams":batsmenTeams,'Rating':batsmenRatings}
odibatsmen_df=pd.DataFrame(odibatsmen_dict)
odibatsmen_df
# Out:
#                 Name Teams  Rating
# 0       Alyssa Healy   AUS     785
# 1     Natalie Sciver   ENG     750
# 2        Beth Mooney   AUS     748
# 3    Laura Wolvaardt    SA     722
# 4        Meg Lanning   AUS     710
# 5     Rachael Haynes   AUS     701
# 6        Mithali Raj   IND     686
# 7  Amy Satterthwaite    NZ     681
# 8    Smriti Mandhana   IND     669
# 9     Tammy Beaumont   ENG     659

# %%
#c) Top 10 women’s ODI all-rounder along with the records of their team and rating

Allrounder_dict={'Name':allrounderNames,"Teams":allrounderTeams,'Rating':allrounderRatings}
odiwomenallrounder_df=pd.DataFrame(Allrounder_dict)
odiwomenallrounder_df
# Out:
#                 Name Teams  Rating
# 0     Natalie Sciver   ENG     393
# 1     Natalie Sciver   ENG     750
# 2        Beth Mooney   AUS     748
# 3    Laura Wolvaardt    SA     722
# 4        Meg Lanning   AUS     710
# 5     Rachael Haynes   AUS     701
# 6        Mithali Raj   IND     686
# 7  Amy Satterthwaite    NZ     681
# 8    Smriti Mandhana   IND     669
# 9     Tammy Beaumont   ENG     659

# %% [markdown]
# # 7) Write a python program to scrape details of all the posts from coreyms.com. Scrape the heading, date, content and the code for the video from the link for the youtube video from the post

# %%
#Creating the dataframe
coreyms_dic={'Heading':heading,'Time':time,'Content':content,"Video_link":videoCode}
coreyms_DataFrame=pd.DataFrame(coreyms_dic)

coreyms_DataFrame
# Out:
#                                              Heading                Time  \
# 0  Python Tutorial: Zip Files – Creating and Extr...   November 19, 2019
# 1  Python Data Science Tutorial: Analyzing the 20...    October 17, 2019
# 2  Python Multiprocessing Tutorial: Run Code in P...  September 21, 2019
# 3  Python Threading Tutorial: Run Code Concurrent...  September 12, 2019
# 4                                Update (2019-09-03)   September 3, 2019
# 5  Python Quick Tip: The Difference Between “==” ...      August 6, 2019
# 6  Python Tutorial: Calling External Commands Usi...       July 24, 2019
# 7  Visual Studio Code (Windows) – Setting up a Py...         May 1, 2019
# 8  Visual Studio Code (Mac) – Setting up a Python...         May 1, 2019
# 9  Clarifying the Issues with Mutable Default Arg...      April 24, 2019
#
#                                              Content  \
# 0  \nIn this video, we will be learning how to cr...
# 1  \nIn this Python Programming video, we will be...
# ...

# %% [markdown]
# # 8. Write a python program to scrape house details from mentioned URL. It should include house title, location, area, EMI and price from https://www.nobroker.in/ .Enter three localities which are Indira Nagar, Jayanagar, Rajaji Nagar

# %%
#Creating a data Frame
House_Details_dic={'House Details':house,"Location":loc,'Area':house_AREA,'EMI':house_EMI,"Price":house_Price}
House_Details_DataFrame=pd.DataFrame(House_Details_dic)
House_Details_DataFrame
# Out:
#                                         House Details  \
# 0   4+ BHK In Independent House  For Sale  In Indi...
# 1   3 BHK Flat  For Sale  In Rrbc Piccassso In Jay...
# 2   4+ BHK In Independent House  For Sale  In Raja...
# 3   4 BHK In Independent House  For Sale  In Jayan...
# 4   3 BHK Flat  For Sale  In Shree Rameshwara Nila...
# 5   4+ BHK In Independent House  For Sale  In Raja...
# 6   3 BHK Apartment  For Sale  In Laa Royal Manor ...
# 7   2 BHK Flat  For Sale  In Pallava Terrace In Ja...
# 8   4+ BHK In Independent House  For Sale  In Raja...
# 9   3 BHK Apartment  For Sale  In Admiralty Manor,...
# 10  2 BHK Apartment  For Sale  In Jains Prakriti I...
# 11  3 BHK Flat  For Sale  In Benaka Apartments In ...
# 12  4 BHK In Independent House  For Sale  In Indir...
# 13  2 BHK Apartment  For Sale  In Blueberry Apartm...
# 14  4+ BHK In Independent House  For Sale  In Laks...
# 15  2 BHK Apartment  For Sale  In Tarang Parkway A...
# ...

# %% [markdown]
# # 9) Write a python program to scrape mentioned details from dineout.co.in :
# i) Restaurant name
#
# ii) Cuisine
#
# iii) Location
#
# iv) Ratings
#
# v) Image URL

# %%
#Creating the data frame
df=pd.DataFrame({'Restaurants':restaurants,'Cuisine':cuisine,'Locations':locations,'Image_URL':image})
df
# Out:
#                                           Restaurants  \
# 0               TamashaConnaught Place, Central Delhi
# 1   LocalScindia House,Connaught Place, Central Delhi
# 2   Unplugged CourtyardConnaught Place, Central Delhi
# 3   The G.T. ROADM-Block,Connaught Place, Central ...
# 4   Ministry Of BeerM-Block,Connaught Place, Centr...
# 5   Connaught Clubhouse MicrobreweryConnaught Plac...
# 6        Openhouse CafeConnaught Place, Central Delhi
# 7     The Junkyard CafeConnaught Place, Central Delhi
# 8        Warehouse CafeConnaught Place, Central Delhi
# 9   Chili's American Grill and BarM-Block,Connaugh...
# 10  High 5 - Everyday Wholesale BarConnaught Place...
# 11                  QBAConnaught Place, Central Delhi
# 12              Berco'sConnaught Place, Central Delhi
# 13   Lord of the DrinksConnaught Place, Central Delhi
# 14               SandozConnaught Place, Central Delhi
# 15                ChidoConnaught Place, Central Delhi
# ...

# %% [markdown]
# # 10) Write a python program to scrape first 10 product details which include product name , price , Image URL from https://www.bewakoof.com/women-tshirts?ga_q=tshirts .

# %%
#DataFrame of first 10 product details
product_details=pd.DataFrame({"Product Name":product,"Price":price,"Image URL":image})
product_details
# Out:
#                                         Product Name  Price  \
# 0  Women's Black The Peanuts Beatles Graphic Prin...  ₹ 349
# 1  Women's Green No Prince, No Problem Graphic Pr...  ₹ 349
# 2  Women's Pink No Prince, No Problem Graphic Pri...  ₹ 349
# 3  Women's Black Tie & Dye Oversized T-shirt₹ 799...  ₹ 799
# 4  Women's Yellow Chennai City Boyfriend Typograp...  ₹ 599
# 5  Women's Black Tropical Vibes Typography Oversi...  ₹ 349
# 6  Women's Black This World is Rotten Graphic Pri...  ₹ 599
# 7  Women's White Zenitsu Graphic Printed Oversize...  ₹ 599
# 8  Women's Black Unless You are Korean Typography...  ₹ 599
# 9  Women's White This World is Rotten Graphic Pri...  ₹ 599
#
#                                            Image URL
# 0  https://images.bewakoof.com/t320/the-peanuts-b...
# 1  https://images.bewakoof.com/t320/no-problem-ov...
# 2  https://images.bewakoof.com/t320/no-problem-ov...
# 3  https://images.bewakoof.com/t320/women-s-black...
# ...
